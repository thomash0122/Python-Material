# %% [markdown]
# # Python Pandas

# %% [markdown]
# Pandas is a Python module for working with tabular data (i.e., data in a table with rows and columns).
#
# Tabular data has a lot of the same functionality as SQL or Excel, but Pandas adds the power of Python.

# %% [markdown]
# ## Importing the Pandas Module

# %% [markdown]
# In order to get access to the Pandas module, we’ll need to install the module and then import it into a Python file.

# %%
import pandas

# %% [markdown]
# We can also specify a alias for the pandas module:

# %%
import pandas as pd

# %% [markdown]
# If we need to access the pandas module, we can do so by operating on pd.

# %% [markdown]
# In this lesson, you’ll learn the basics of working with a single table in Pandas, such as:
#
# * Create a table from scratch
#
# * Loading data from another file
#
# * Selecting certain rows or columns of a table

# %% [markdown]
# ## Create a DataDrame

# %% [markdown]
# A DataFrame is an object that stores data as rows and columns.
#
# You can think of a DataFrame as a spreadsheet or as a SQL table.
#
# You can manually create a DataFrame or fill it with data from:
#
# * CSV
#
# * an Excel spreadsheet
#
# * a SQL query

# %% [markdown]
# DataFrames have
#
# * rows
#     * Each column has a name, which is a string.
#
# * columns
#     * Each row has an index, which is an integer.
#
# DataFrames can contain many different data types:
#
# * strings
#
# * ints
#
# * floats
#
# * tuples
#
# * etc

# %% [markdown]
# To create a dataframe, we can pass in a dictionary to pd.DataFrame().

# %% [markdown]
# Each key is a column name and each value is a list of column values.
#
# The columns must all be the same length or you will get an error.

# %% [markdown]
# syntax:

# %%
import pandas as pd

df_name = pd.DataFrame ({
    "column1": ["column1_value1", "column1_value2", "column1_value3"], 
    "column2": ["column2_value1", "column2_value2", "column2_value3"]
})

# %% [markdown]
# Example:

# %%
df1 = pd.DataFrame({
    'name': ['John Smith', 'Jane Doe', 'Joe Schmo'],
    'address': ['123 Main St.', '456 Maple Ave.', '789 Broadway'],
    'age': [34, 28, 51]
})
