# %% [markdown]
# # Pie Chart

# %% [markdown]
# If we want to display elements of a data set as proportions of a whole, we can use a pie chart.
#
# Pie charts are helpful for displaying data like:
#
# * Different ethnicities that make up a school district
# * Different macronutrients (carbohydrates, fat, protein) that make up a meal
# * Different responses to an online poll

# %% [markdown]
# Syntax:

# %%
plt.pie(data_list)

# %% [markdown]
# Example:

# %%
import matplotlib.pyplot as plt
payment_method_names = ["Card Swipe", "Cash", "Apple Pay", "Other"]
payment_method_freqs = [270, 77, 32, 11]

plt.pie(payment_method_freqs)
plt.show()

# %% [markdown]
# ## Pie Chart Labeling

# %% [markdown]
# To put labeling on the pie chat, we can either:
#
# * use a legend to label each color
# * put labels on the chart itself.

# %% [markdown]
# ### Legend

# %% [markdown]
# Syntax:

# %%
plt.legend(name_list)

# %% [markdown]
# Example:

# %%
budget_data = [500, 1000, 750, 300, 100]
budget_categories = ['marketing', 'payroll', 'engineering', 'design', 'misc']

plt.pie(budget_data)
plt.legend(budget_categories)
plt.show()

# %% [markdown]
# ### Label on chart

# %%
plt.pie(data_list, labels=name_list)

# %% [markdown]
# Example:

# %%
budget_data = [500, 1000, 750, 300, 100]
budget_categories = ['marketing', 'payroll', 'engineering', 'design', 'misc']

plt.pie(budget_data, labels=budget_categories)
plt.show()

# %% [markdown]
# ## Label Percentage in Pie chart

# %% [markdown]
# One other useful labeling tool for pie charts is adding the percentage of the total that each slice occupies.

# %% [markdown]
# Syntax:

# %%
plt.pie(data_list, labels=name_list, autopct="str_format")

# %% [markdown]
# We pass in string formatting instructions to format the labels how we want. Some common formats are:
#
# * '%0.2f' — 2 decimal places, like 4.08
# * '%0.2f%%' — 2 decimal places, but with a percent sign at the end, like 4.08%. You need two consecutive percent signs because the first one acts as an escape character, so that the second one gets displayed on the chart.
# * '%d%%' — rounded to the nearest int and with a percent sign at the end, like 4%.

# %% [markdown]
# Example:

# %%
payment_method_names = ["Card Swipe", "Cash", "Apple Pay", "Other"]
payment_method_freqs = [270, 77, 32, 11]

plt.pie(payment_method_freqs, autopct="%0.1f%%")
plt.legend(payment_method_names)
plt.show()

# %% [markdown]
# ## Graphing Pie Chart with DataFrame

# %% [markdown]
# Given we have a Dataframe with 2 columns:
# * labels
# * frequency/proportion

# %% [markdown]
# To graph a pie chart with DataFrame,

# %% [markdown]
# Syntax:

# %%
import matplotlib.pyplot

plt.pie(df_name["frequency_column"])

# %% [markdown]
# Example:

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(
    [["A",0.09],
     ["B",0.28],
     ["C",0.41],
     ["D",0.18],
     ["E",0.04]],
    columns=["Grade","Proportion"]
)
df
# Out:
#   Grade  Proportion
# 0     A        0.09
# 1     B        0.28
# 2     C        0.41
# 3     D        0.18
# 4     E        0.04

# %%
plt.pie(df["Proportion"],labels=df["Grade"],autopct='%d%%')
plt.show()

# %% [markdown]
# There are 2 situations where pie chart hard to provide insight
# * **when each slices on the pie chart are roughly the same**
#     * Then Bar plot is better for visualization
# * **when there are too many categories**
#     * Then it is better to aggregate. the categories
