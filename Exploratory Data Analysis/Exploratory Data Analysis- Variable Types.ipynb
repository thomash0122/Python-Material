# %% [markdown]
# # Assessing Variable Types

# %% [markdown]
# Variables define datasets.
#
# They are the characteristics or attributes that we evaluate during data collection. There are two ways to do that evaluation:
# * we can measure
# * we can categorizeb
#
# How we evaluate determines what kind of variable we have. Since there are only two ways to get data, there are only two types of variables:
#
# * numerical
# * categorical

# %% [markdown]
# Example:

# %% [markdown]
# Given a Dataset: cereal

# %%
print(cereal.head())

# %% [markdown]
# |	|id	|name	|mfr	|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|Nestle	|C	|10.0|	68.40|	top|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|Quaker Oats|	C|	2.0|	33.98|	top|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|Kelloggs|	C|	9.0	|59.43|	top|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|Kelloggs|	C|	14.0|	93.70|	top|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|Ralston P..|	C|	1.0	|34.38|	top	|25	|1	|5.21|

# %% [markdown]
# There are several types of variables.
#
# For example:
#
# The price column describes how much the cereal costs. We don’t know if that’s how much the consumer pays or the grocer pays, but we can be fairly sure that it’s a numerical variable.
#
# In the mfr column, there are labels like Nestle, Quaker Oats, and Kelloggs, which seem like brands.
# Since brands are categories, mfr is most likely a categorical variable.
#
# The id column also has numbers, but we can assume that since it’s the id, it’s not actually representing a value. It’s probably the label for the observation. Since it’s a label, even though it’s a number, id is a categorical variable.

# %% [markdown]
# ## Categorical Variable

# %% [markdown]
# Categorical variables come in 3 types:
#
# * Nominal variables, which describe something
# * Ordinal variables, which have an inherent ranking
# * Binary variables, which have only two possible variations

# %% [markdown]
# ### Nominal Variables

# %% [markdown]
# When we want to describe something about the world, we need a nominal variable.
#
# Nominal variables are usually words (i.e., red, yellow, blue or hot, cold), but they can also be numbers (i.e., zip codes or user id’s).
#
# Often, nominal variables describe something with a lot of variation. It can be hard to capture all of that variation

# %% [markdown]
# ### Ordinal Variables

# %% [markdown]
# When our categories have an inherent order, we need an ordinal variable.
#
# Ordinal variables are usually described by numbers like 1st, 2nd, 3rd. Places in a race, grades in school, and the scales in survey responses (Likert Scales) are ordinal variables.
#
# Ordinal variables can be a little tricky because even though they are numbers, it doesn’t make sense to do math on them.
#
# For example, let’s say an Olympian won a Gold medal (1st place) and a Bronze medal (3rd place). We wouldn’t say that they averaged Silver medals (2nd place).

# %% [markdown]
# ### Binary Variables

# %% [markdown]
# When there are only two logically possible variations, we need a binary variable.
#
# Binary variables are things like on/off, yes/no, and TRUE/FALSE.
#
# If there is any possibility of a third option, it is not a binary variable.

# %% [markdown]
# Example:

# %% [markdown]
# Given a Dataset: cereal

# %%
print(cereal.head())

# %% [markdown]
# |	|id	|name	|mfr	|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|Nestle	|C	|10.0|	68.40|	top|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|Quaker Oats|	C|	2.0|	33.98|	top|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|Kelloggs|	C|	9.0	|59.43|	top|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|Kelloggs|	C|	14.0|	93.70|	top|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|Ralston P..|	C|	1.0	|34.38|	top	|25	|1	|5.21|

# %% [markdown]
# The name, mfr, shelf is an example: nominal categorical variables. We know this because they are written in descriptive words or letters.
#
# A little less obvious is the type column. They are all ‘C’, which could be a ranking (A, B, C, and therefore an ordinal variable) or it could be a description and therefore a nominal variable. We would have to return to the data dictionary to find out for certain.
#
# The id field may also cause confusion. It’s a number, but it’s not a count or a measurement. Rather, ‘id’ is a categorical variable since it is describing each observation in the same way that the name is.

# %% [markdown]
# ## Numerical Variable

# %% [markdown]
# Numerical variables are created two ways:
# * measurement
# * counting
#
# The result is continuous and discrete variables.

# %% [markdown]
# ### Continuous Variables

# %% [markdown]
# Continuous variables come from measurements.
#
# For a variable to be continuous, there must be infinitely smaller units of measurement between one unit and the next unit.
#
# Continuous variables can be represented by decimal places (but because of rounding, sometimes they are whole numbers).
#
# Length, time, and temperature are all good examples of continuous variables because they all increase continuously.

# %% [markdown]
# ### Discrete Variables

# %% [markdown]
# Discrete variables come from counting.
#
# For a variable to be discrete, there must be gaps between the smallest possible units.
#
# People, cars, and dogs are all good examples of discrete variables.

# %% [markdown]
# Example:

# %% [markdown]
# Given a Dataset: cereal

# %%
print(cereal.head())

# %% [markdown]
# |	|id	|name	|mfr	|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|Nestle	|C	|10.0|	68.40|	top|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|Quaker Oats|	C|	2.0|	33.98|	top|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|Kelloggs|	C|	9.0	|59.43|	top|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|Kelloggs|	C|	14.0|	93.70|	top|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|Ralston P..|	C|	1.0	|34.38|	top	|25	|1	|5.21|

# %% [markdown]
# There are five numerical variables:
#
# * fiber
# * rating
# * vitamins
# * coupons
# * price
#
# Fiber, rating, and price all have decimal places.
#
# That’s our first clue that they might be continuous.
#
# Based on our limited knowledge, we might guess that fiber and rating are both continuous measurements that could have more decimal places, and price is discrete because there’s nothing smaller than a cent.

# %% [markdown]
# Vitamins and coupons do not have decimal places.
#
# Vitamins and coupons both seem like good candidates to be counts and therefore discrete. The answers to “how many vitamins” and “how many coupons” would both be whole numbers.

# %% [markdown]
# ## Acccess Variable DataType in python

# %% [markdown]
# To access the datatype of each column in python, we can use the .dtypes

# %% [markdown]
# syntax:

# %% [markdown]
# print(df_name.dtypes)

# %% [markdown]
# Example:

# %% [markdown]
# Given a Dataset: cereal

# %%
print(cereal.head())

# %% [markdown]
# |	|id	|name	|mfr	|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|Nestle	|C	|10.0|	68.40|	top|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|Quaker Oats|	C|	2.0|	33.98|	top|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|Kelloggs|	C|	9.0	|59.43|	top|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|Kelloggs|	C|	14.0|	93.70|	top|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|Ralston P..|	C|	1.0	|34.38|	top	|25	|1	|5.21|

# %%
print(cereal.dtypes)

# %% [markdown]
# |name|	object|
# |---|---|
# |id	|int64|
# |name|	object|
# |mfr	|object|
# |type|	object|
# |fiber|	float64|
# |rating	|float64|
# |shelf|	object|
# |vitamins|	int64|
# |coupons|	int64|
# |price|	float64|
# |dtype: object|

# %% [markdown]
# Best practices for data storage say that we should match the data type of the column with its real-world variable type. Therefore:
#
# Continuous (numerical) variables should usually be stored as the *float* data type because they allow us to store decimal values.
#
# Discrete (numerical) variables should be stored as the *int* datatype to represent mathematically that they are discrete.

# %% [markdown]
# ### Changing Numerical Variable Data Types

# %% [markdown]
# If a variable appears with the wrong data type, we can change it with the .astype() function.

# %% [markdown]
# sytax:

# %%
# df_name["column_name"] = df_name["column_name"].astype("type_name")

# %% [markdown]
# The .astype() function can be used to convert between a numerical data types, including:
#
# * int32 int64
# * float32 float64
# * object
# * string
# * bool

# %% [markdown]
# However, some data types require all values to be filled in.
#
# For example, you cannot convert between a float and an int if there are any null values.

# %% [markdown]
# Example:

# %% [markdown]
# Given a Dataset: cereal

# %%
print(cereal.head())

# %% [markdown]
# |	|id	|name	|mfr	|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|Nestle	|C	|10.0|	68.40|	top|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|Quaker Oats|	C|	2.0|	33.98|	top|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|Kelloggs|	C|	9.0	|59.43|	top|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|Kelloggs|	C|	14.0|	93.70|	top|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|Ralston P..|	C|	1.0	|34.38|	top	|25	|1	|5.21|

# %%
print(cereal.dtypes)

# %% [markdown]
# |name|	object|
# |---|---|
# |id	|int64|
# |name|	object|
# |mfr	|object|
# |type|	object|
# |fiber|	float64|
# |rating	|float64|
# |shelf|	object|
# |vitamins|	int64|
# |coupons|	int64|
# |price|	float64|
# |dtype: object|

# %% [markdown]
# Notice the name, mfr, type, shelf are coded as object. We need to change to their appropreiate datatype.
#
# "name", "mfr", "type", "shelf" consists of words so it should be "string"

# %% [raw]
# cereal["name"] = cereal["name"].astype("string")
# cereal["mfr"] = cereal["mfr"].astype("string")
# cereal["type"] = cereal["type"].astype("string")
# cereal["shelf"] = cereal["shelf"].astype("string")

# %%
print(cereal.dtypes)

# %% [markdown]
# |name|	object|
# |---|---|
# |id	|int64|
# |name|	string|
# |mfr	|string|
# |type|	string|
# |fiber|	float64|
# |rating	|float64|
# |shelf|	string|
# |vitamins|	int64|
# |coupons|	int64|
# |price|	float64|
# |dtype: object|

# %% [markdown]
# ## Data Type: Category

# %% [markdown]
# By default, Python doesn't know if the given data column should represent it in the form of category.
#
# So we need to manully set the data column to category.

# %% [markdown]
# The pandas .Categorical() method can be used to store data as type category and indicate the order of the categories.

# %% [markdown]
# To convert the datatype of the give data column to categorical:

# %% [markdown]
# First we need to find the categories of the data column, we can do so by using unique() method:

# %%
df_name.column_name.unique()

# %% [markdown]
# Next we can convert the datataype of the column to categorical

# %% [markdown]
# syntax:

# %%
df_name["column_name"] = pd.Categorical(
    df_name["columne_name"], 
    [category1, category2,...], 
    ordered=True
    )

# %% [markdown]
# pd.Categorical() takes in 3 arugments:
#
# * A column in a dataset
# * a list of levels
# * ordered = True/False : if ordered=True, the levels will be sorted which mean rank is assigned from low to high/ small to large. By default, ordered = False

# %% [markdown]
# Example:

# %% [markdown]
# Given a Dataset: cereal

# %%
print(cereal.head())

# %% [markdown]
# |	|id	|name	|mfr	|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|Nestle	|C	|10.0|	68.40|	top|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|Quaker Oats|	C|	2.0|	33.98|	top|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|Kelloggs|	C|	9.0	|59.43|	top|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|Kelloggs|	C|	14.0|	93.70|	top|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|Ralston P..|	C|	1.0	|34.38|	top	|25	|1	|5.21|

# %%
print(cereal.dtypes)

# %% [markdown]
# |name|	object|
# |---|---|
# |id	|int64|
# |name|	string|
# |mfr	|string|
# |type|	string|
# |fiber|	float64|
# |rating	|float64|
# |shelf|	string|
# |vitamins|	int64|
# |coupons|	int64|
# |price|	float64|
# |dtype: object|

# %% [markdown]
# Suppose the values in the "shelf" column is a cateogrical variable. To convert the datatype of "shelf" column:

# %% [markdown]
# First, we need to find the levels of "shelf" column:

# %%
print(cereal.shelf.unique())

# %% [raw]
# ["top", "mid", "bottom"]

# %% [markdown]
# Once we know the levels, we can start to convert the column to category:

# %%
cereal["shelf"] = pd.Categorical(cereal["shelf"], ["bottom", "mid", "top"]

# %% [markdown]
# When we check the datatype of eah column in cereal again:

# %%
print(cereal.dtypes)

# %% [markdown]
# |name|	object|
# |---|---|
# |id	|int64|
# |name|	string|
# |mfr	|string|
# |type|	string|
# |fiber|	float64|
# |rating	|float64|
# |shelf|	category|
# |vitamins|	int64|
# |coupons|	int64|
# |price|	float64|
# |dtype: object|

# %% [markdown]
# The datatype of "shelf" is no longer "string" but an "category"

# %% [markdown]
# And also when we do unique():

# %%
print(cereal.shelf.unique())

# %%
[bottom, mid, top]
Categories (6, object): [bottom < mid < top]

# %% [markdown]
# It shows the levels be a cateogry, and as well as the ranking in order from low to high.

# %% [markdown]
# ## One-Hot Encoding

# %% [markdown]
# One-Hot Encoding (OHE) is a special way of treating categorical data column.
#
# OHE converts categorical data into numerical data by creating new data column for each levels:
#
# * when the row data match with the level, then value would be 1
# * when the row data doesn't match with the level, then value would be 0
#
# The data column created is called dummy variable

# %% [markdown]
# Illustration:

# %% [markdown]
# Given a Dataset: cereal

# %%
print(cereal.head())

# %% [markdown]
# |	|id	|name	|mfr	|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|Nestle	|C	|10.0|	68.40|	top|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|Quaker Oats|	C|	2.0|	33.98|	top|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|Kelloggs|	C|	9.0	|59.43|	top|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|Kelloggs|	C|	14.0|	93.70|	top|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|Ralston P..|	C|	1.0	|34.38|	top	|25	|1	|5.21|

# %% [markdown]
# Suppose we want to do OHE on the "mfr" column, the graphical representation:

# %% [markdown]
# Before:

# %% [markdown]
# |	|id	|name	|mfr	|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|Nestle	|C	|10.0|	68.40|	top|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|Quaker Oats|	C|	2.0|	33.98|	top|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|Kelloggs|	C|	9.0	|59.43|	top|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|Kelloggs|	C|	14.0|	93.70|	top|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|Ralston P..|	C|	1.0	|34.38|	top	|25	|1	|5.21|

# %% [markdown]
# After:

# %% [markdown]
# |	|id	|name	|Nestle|Quaker Oats|Kelloggs|Ralston P..|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|1|0|0|0|C	|10.0|	68.40|	top|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|0|1|0|0|	C|	2.0|	33.98|	top|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|0|0|1|0|	C|	9.0	|59.43|	top|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|0|0|1|0|	C|	14.0|	93.70|	top|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|0|0|0|1|	C|	1.0	|34.38|	top	|25	|1	|5.21|

# %% [markdown]
# The "mfr" column split into 4 columns. Each columns represent each category with the value: 0 and 1

# %% [markdown]
# To perform OHE in Python:

# %% [markdown]
# syntax:

# %%
df_name = pd.ger_dummies(
    data=df_name,
    columns=["column_name1", "column_name2", ...]
)

# %% [markdown]
# Example:

# %% [markdown]
# To perform OHE on the "mfr" column in python:

# %%
cereal = pd.get_dummies(
    data = cereal,
    columns = ["mfr"]
)

# %% [markdown]
# It is important to note that OHE works best when we do not create too many additional variables, as increasing the dimensionality of our dataframe can create problems when working with certain machine learning models.

# %% [markdown]
# ## Numerical representation of Categorical Variable

# %% [markdown]
# We can also use integer to represent the levels in categorical data column.

# %% [markdown]
# To do so, we must first convert the data column into categorical datatype and then assign integer to the levels

# %% [markdown]
# syntax:

# %%
df_name["column_name"] = df_name["column_name"].cat.codes

# %% [markdown]
# Example:

# %% [markdown]
# Given a Dataset: cereal

# %%
print(cereal.head())

# %% [markdown]
# |	|id	|name	|mfr	|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|Nestle	|C	|10.0|	68.40|	top|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|Quaker Oats|	C|	2.0|	33.98|	top|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|Kelloggs|	C|	9.0	|59.43|	top|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|Kelloggs|	C|	14.0|	93.70|	top|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|Ralston P..|	C|	1.0	|34.38|	top	|25	|1	|5.21|

# %% [markdown]
# Suppose we want to represent the "shelf" column as categorical variable but in numerical way

# %% [markdown]
# First we need to convert "shelf" into categorical:

# %%
cereal["shelf"] = pd.Categorical(
    cereal["shelf"],
    ["buttom", "mid", "top"]
    ordered = True
)

# %% [markdown]
# And then we can convert the levels in "shelf" into numeric using .cat.codes()

# %%
cereal["shelf"] = cereal.shelf.cat.codes

# %%
print(cereal.head())

# %% [markdown]
# |	|id	|name	|mfr	|type|	fiber	|rating|	shelf|	vitamins|	coupons|	price|
# |---|---|---|---|---|---|---|---|---|---|---|
# |0|	22341|	100% Bran…	|Nestle	|C	|10.0|	68.40|	2|	25|	4	|3.46|
# |1|	22791|	100% Natur…	|Quaker Oats|	C|	2.0|	33.98|	2|	0	|1	|3.36|
# |2|	98141|	All-Bran…	|Kelloggs|	C|	9.0	|59.43|	2|	25	|4	|2.07|
# |3|	20001|	All-Bran w…	|Kelloggs|	C|	14.0|	93.70|	2|	25|	3	|3.57|
# |4|	67121|	Almond Del…	|Ralston P..|	C|	1.0	|34.38|	2	|25	|1	|5.21|

# %% [markdown]
# Now the resulting "shelf" column is represented as categorical but in a numeric way. Since we specified the "ordered" arugment, so "0" is "buttom", "1" is "mid", and "2" is "top"
